# %% [markdown]
# <img src="https://static.wincacademy.nl/logos/main-logo.png" height=200px style="height: 200px"/>

# %%
# !pip install matplotlib --user > /dev/null 2>&1
# !pip install numpy --user > /dev/null 2>&1
# !pip install pandas --user > /dev/null 2>&1

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import csv

# %% [markdown]
# # Data Preparation
#
# ## CSV
#
# Let's talk about the messy part of data analytics: preparing data. Before doing the interesting work of data analytics, we need to:
#
# 1. Gather the data.
# 2. Structure the data in such a way that we can work with it in our programs.
# 3. Clean the data, which may include dealing with missing or unreasonable values.
#
# Here we'll assume gathering the data has been done for us. We'll use a dataset provided by the Dutch *Rijksinstituut voor Volksgezondheid en Milieu* (RIVM, translation: National Institute for Health and Environment). It contains COVID-19 numbers per municipality per day. You should place a copy of the data in a file called `covid-data.csv` located in the same folder as this notebook (be it in Google Colab or locally). You can use the URL below to retrieve it.
#
# - Source: Rijksinstituut voor Volksgezondheid en Milieu
# - Data URL: https://data.rivm.nl/covid-19/COVID-19_aantallen_gemeente_per_dag.csv

# %%
data_loc = 'covid-data.csv'
covid_data = open(data_loc).read()

# %% [markdown]
# Let's take a look at what it looks like by printing the first 1000 characters.

# %%
print(covid_data[:1000])
# Out:
# Date_of_report;Date_of_publication;Municipality_code;Municipality_name;Province;Security_region_code;Security_region_name;Municipal_health_service;ROAZ_region;Total_reported;Hospital_admission;Deceased
# 24-3-2021 10:00;27-2-2020;GM0014;Groningen;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0034;Almere;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0037;Stadskanaal;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0047;Veendam;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0050;Zeewolde;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0059;Achtkarspelen;Fryslân;VR02;Fryslân;GGD Fryslân;Acute Zorgnetwerk Noord Nederland;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0060;Ameland;Fryslân;VR02;Fryslân;GGD Fryslân;Acute Zorgnetwerk Noord Nederland;0;0;0

# %% [markdown]
# That looks pretty chaotic. The data is in a format called `csv`, which is a commonly used format to store and share data.
#
# 1. A `csv` file contains only text.
# 2. The first line a `csv` file lists column names.
# 3. Each line after that is a datapoint with values for those columns in the same order.
#
# Let's look at the first 3 lines instead of the first 1000 characters.

# %%
for line in covid_data.split('\n')[:3]:
    print(line)
# Out:
# Date_of_report;Date_of_publication;Municipality_code;Municipality_name;Province;Security_region_code;Security_region_name;Municipal_health_service;ROAZ_region;Total_reported;Hospital_admission;Deceased
# 24-3-2021 10:00;27-2-2020;GM0014;Groningen;Groningen;VR01;Groningen;GGD Groningen;Acute Zorgnetwerk Noord Nederland;0;0;0
# 24-3-2021 10:00;27-2-2020;GM0034;Almere;Flevoland;VR25;Flevoland;GGD Flevoland;SpoedZorgNet;0;0;0

# %% [markdown]
# **1. What are the column names for this dataset? List them here.**
#
# *TODO: Your answer here.*
#
# - Eerste kolom: Date_of_report
# - Tweede kolom : Date_of_publication
# - Derde Kolom: Municipality_code
# - vierde kolom: MunMunicipality_name
# - vijfde kolom: Province
# - zesde kolom: Security_region_code
# - zevende kolom: Security_region_name
# - achtste kolom: Municipal_health_service
# - negende kolom: ROAZ_region
# - tiende kolom: Total_reported
# - elfde kolom: Hospital_admission
# - twaalfde kolom: Deceased
#
# **2. Which character separates the datapoints from each other? Put an `x` in the right box.**
#
# - [X] A linebreak
# - [ ] A tab
# - [ ] A comma
#
#
# **3. Which character separates the columns within a datapoint from each other?**
#
# Puntkomma
#
#
# ### Parsing
#
# Let's use this information to read the data into our program in a better way. This is known as [*parsing*](https://en.wikipedia.org/wiki/Parsing). Our goal is to structure the data in such a way that we'll be able to write code like this to make it easier to work with the data:
#
# ```python
# # For some datapoint, show me the municipality that it concerns.
# some_datapoint['Municipality_name']
# ```
#
# By answering the questions above we have all the information we need to organize the internal *data structure* in this way.
#
# - We know what separates datapoints from each other.
# - We know how columns are separated within datapoints.
# - We have the column names for each datapoint.
#
# We can use this information to instruct Python -- the programming language we're using here -- to create a *data structure* that we can use like in the example above. Once completed, we'll have *parsed* the CSV file.
#
# **4. What is parsing in your own words?**
#
# Tekst omzetten in bruikbare data
#
# **5. Fill in the right column delimiter in the code cell below to complete the code.**

# %%
# TODO: Change PLACEHOLDER to the actual delimiter.
delimiter =';'
# Make sure the delimiter is surrounded by quotes, for example: delimiter = '<' if the delimiter is <

with open(data_loc) as f:
    csv_reader = csv.DictReader(f, delimiter=delimiter)
    print('Municipality name\tTotal cases reported')
    print('{:=>45}'.format(''))
    data_dicts = list(csv_reader)

for row in data_dicts[:15]:
    print('{:<23} {:<5}'.format(row['Municipality_name'], row['Total_reported']))
# Out:
# Municipality name	Total cases reported
# =============================================
# Groningen               0
# Almere                  0
# Stadskanaal             0
# Veendam                 0
# Zeewolde                0
# Achtkarspelen           0
# Ameland                 0
# Harlingen               0
# Heerenveen              0
# Leeuwarden              0
# Ooststellingwerf        0
# Opsterland              0
# Schiermonnikoog         0
# Smallingerland          0
# Terschelling            0

# %% [markdown]
# Note: Your delimiter was not filled in (correctly) if you got one of these errors:
#
# ```python
# TypeError: "delimiter" must be a 1-character string
# KeyError: 'Municipality_name'
# ```
#
# ## Metadata
#
# Alright, this is much better that looking at raw text, like we did before parsing. We'll get to even better views of the data later. First, let's take a look at some *metadata* -- data about data.
# - The number of datapoints
# - The number of columns
# - The names of the columns (again)
# - The number of missing or empty values
# - The number of unique values in each column

# %%
from collections import defaultdict

print(f'Number of datapoints: {len(data_dicts)}')
print(f'Number of columns: {len(data_dicts[0])}')
print('Column names:')
for k in data_dicts[0].keys():
    print(f'- {k}')
    
unique_vals = [set() for _ in data_dicts[0].keys()]
missing = 0
for datapoint in data_dicts:
    for i, val in enumerate(datapoint.values()):
        unique_vals[i].add(val)
        if val is None or val == '':
            missing += 1
print(f'Missing/empty values: {missing}')

print('Number of unique values:')
for i, k in enumerate(data_dicts[0].keys()):
    print('- {:<25}{:5}'.format(k, len(unique_vals[i])))
# Out:
# Number of datapoints: 362817
# Number of columns: 12
# Column names:
# - Date_of_report
# - Date_of_publication
# - Municipality_code
# - Municipality_name
# - Province
# - Security_region_code
# - Security_region_name
# - Municipal_health_service
# - ROAZ_region
# - Total_reported
# - Hospital_admission
# - Deceased
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-fd5a4d647702> in <module>()
#      11 for datapoint in data_dicts:
#      12     for i, val in enumerate(datapoint.values()):
# ---> 13         unique_vals[i].add(val)
#      14         if val is None or val == '':
#      15             missing += 1
#
# IndexError: list index out of range

# %% [markdown]
# **6. Note three questions that you have about the data based on this metadata. It might be something like:**
#
# > **"What is the first and last *date of publication* in the dataset?"**
#
# 1. Welke provincies zijn er in de dataset
# 2. Welke regio's zijn er in de dataset
# 3. Uit welke gemeente komt de dataset?
#
#
# **7. Note another metadata property that you would like to know about that's not listed here.**
#
# Hoeveel hebben er voor de 2e keer corona gehad?
#
# ## Working with dates
#
# Looking at the metadata is a good way to get a feel for what a dataset looks like, and what type of questions you can answer with it. Let's use our example question to proceed with data preparation:
#
# > What is the first and last *date of publication* in the dataset?
#
# To answer this question, we can't just assume the first date is at the top and the last date is at the bottom, or vice versa. We need some way to do compare the dates and find out which one is the first and which one is the last. Let's first inspect a few entries in the `Date_of_publication` column to see what they look like.

# %%
print('The current datatype for the Date_of_publication column is:', type(data_dicts[0]['Date_of_publication']))
for row in data_dicts[::int(len(data_dicts) / 20)]:
    print(row['Date_of_publication'])
# Out:
# The current datatype for the Date_of_publication column is: <class 'str'>
# 27-2-2020
# 28-5-2020
# 23-6-2020
# 24-4-2020
# 5-9-2020
# 10-9-2020
# 24-8-2020
# 25-6-2020
# 7-11-2020
# 30-9-2020
# 8-12-2020
# 28-8-2020
# 27-11-2020
# 4-2-2021
# 9-2-2021
# 2-1-2021
# 29-1-2021
# 20-2-2021
# 19-3-2021
# 4-2-2021
# 24-3-2021

# %% [markdown]
# We see that the data type is `str`, which is short for *string*, the programming term for *text*. We can't do any clever comparing with just text. We need to *parse* these dates to be able to make comparisons between them.
#
# Fortunately, the dates are then specified in a certain *date format*. For example, in the Netherlands people often write '24/12/1980' for the 24th day of December in the year 1980. We could specify that format as `DD/MM/YYYY`.
#
# - `DD` stands for 'Two numbers that represent the day'.
# - `MM` stands for 'Two numbers that represent the month'.
# - `YYYY` stands for 'Four numbers that represent the year'.
#
# If they wrote `-` instead of `/`, like so: '24-12-1980', the format would be `DD-MM-YYYY`.
#
# **8. What is the *date format* in the `Date_of_publication` column in our dataset?**
#
# DD-MM-YYYY
#
# **9. Fill in this format in the placeholder in the code block below.**
#
# - **Use `%Y` for `YYYY`.**
# - **Use `%m` for `MM`.**
# - **Use `%d` for `DD`.**
#
# **For example, the Dutch date format ('DD/MM/YYYY' would be `'%d/%m/%Y'`)**

# %%
from datetime import datetime

# TODO: Fill in date format for PLACEHOLDER in the next line.
date_format = '%Y-%m-%d'
# Don't modify anything below this line.

for row in data_dicts:
    formatted_date = datetime.strptime(row['Date_of_publication'], date_format).date()
    row['Date_of_publication'] = formatted_date
    
print('The new datatype for the Date_of_publication column is:', type(data_dicts[0]['Date_of_publication']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-16bc7c115bed> in <module>()
#       6
#       7 for row in data_dicts:
# ----> 8     formatted_date = datetime.strptime(row['Date_of_publication'], date_format).date()
#       9     row['Date_of_publication'] = formatted_date
#      10
#
# TypeError: strptime() argument 1 must be str, not datetime.date

# %% [markdown]
# If you get an error like the following, your `date_format` is not correct yet.
#
# ```python
# ValueError: time data '2020-02-27' does not match format 'PLACEHOLDER'
# ```
#
# After filling in `date_format` correctly, you should see a line that confirms that the new datatype for this column is `datetime.date`. Great! Now we can compare the dates in the column and answer our original question:
#
# > What is the first and last *date of publication* in the dataset?
#
# We can now compare the dates with:
#
# - `a > b`: this checks if `a` is *later* than `b`.
# - `a < b`: this checks if `a` is *earlier* than `b`.

# %%
# We make the assumption that the date of publication of the first datapoint is the only date. 
first_date_of_publication = data_dicts[0]['Date_of_publication']
last_date_of_publication = data_dicts[0]['Date_of_publication']
# Then we see if we can find any earlier ones, or later ones.
for row in data_dicts:
    # Check if this date is earlier than the currently known first date of publication
    if row['Date_of_publication'] < first_date_of_publication:
        # If so, this is now the new earliest date.
        first_date_of_publication = row['Date_of_publication']
    # Check if this date is later than the currently known last date of publication
    elif row['Date_of_publication'] > last_date_of_publication:
        # If so, this is now the new latest date.
        last_date_of_publication = row['Date_of_publication']

print(f'The first date of publication is {first_date_of_publication}')
print(f'The last date of publication is {last_date_of_publication}')
print(f'The dataset spans {(last_date_of_publication - first_date_of_publication).days} days')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-2b0e63d8f347> in <module>()
#       5 for row in data_dicts:
#       6     # Check if this date is earlier than the currently known first date of publication
# ----> 7     if row['Date_of_publication'] < first_date_of_publication:
#       8         # If so, this is now the new earliest date.
#       9         first_date_of_publication = row['Date_of_publication']
#
# TypeError: '<' not supported between instances of 'str' and 'datetime.date'

# %% [markdown]
# Cool! We now have a better understanding of what the `Date_of_publication` column looks like.
#
# **10. Explain, in your own words, what a string is.**
#
# Als je tussen aanhalingstekens ietst typt is dat een string. Zonder die aanhalingstekens ontstaat er een foutmelding.
#
# **11. Explain, in your own words, what a date string is.**
#
# Een date string geeft aan in welk format de datum moet komen te staan zoals 'dd-mm-yyyy' of yyyy-mm-dd
#
# **12. Explain, in your own words, why we converted date strings to a `datetime.date` type.**
#
# Zodat de datums van elkaar af kunnen worden gehaald en vergeleken kunnen worden met elkaar
#
#
# ## Working with numbers
#
# We'd like to wrap up this lesson with a nice visualization of how many COVID cases were reported over time in a certain municipality. For that we not only have to work with strings and dates, but also with *numbers*. We can find the right number in the `Total_reported` column, but again, it's not yet in the right format. It's a string, while it needs to be a number.
#
# Let's apply the same strategy that we used with dates before. Note that if you run the cell below multiple times, it will no longer show that the column values used to be a strings -- they were converted the first time.

# %%
print('The current datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
for row in data_dicts:
    row['Total_reported'] = int(row['Total_reported'])
print('The new datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
# Out:
# The current datatype for the Total_reported column is: <class 'str'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-2428a4b067f2> in <module>()
#       1 print('The current datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
#       2 for row in data_dicts:
# ----> 3     row['Total_reported'] = int(row['Total_reported'])
#       4 print('The new datatype for the Total_reported column is:', type(data_dicts[0]['Total_reported']))
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'

# %% [markdown]
# The new datatype for the `Total_reported` column is `int`, which stands for *integer*. This is the programming term for *whole number*. Bonus: the term for a decimal number is *float*.
#
# **13. Which variable in the code snippet below is an integer? (write an `x` in the right box)**
#
# ```python
# a = 'Hello, world!'
# b = 42
# ```
#
# - [ ] `a`
# - [X] `b`
#
# **14. Which variable in the code snippet below is an integer? (write an `x` in the right box)**
#
# ```python
# a = '42'
# b = 42
# ```
#
# - [ ] `a`
# - [X] `b`
#
# Now that the `Total_reported` column has the correct datatype, let's write a script that tells us the reported number per municipality. For convenience, we first print a list of all the municipalities in the dataset.
#
# **15. Choose one of the municipalities printed in the code block below. Then fill it in (exactly as it was displayed) in the next cell and run it to find the total number of reported cases in that municipality.**

# %%
for m in sorted(unique_vals[3]):
    if m != '':
        print('-', m)
# Out:
# - 's-Gravenhage
# - 's-Hertogenbosch
# - Aa en Hunze
# - Aalsmeer
# - Aalten
# - Achtkarspelen
# - Alblasserdam
# - Albrandswaard
# - Alkmaar
# - Almelo
# - Almere
# - Alphen aan den Rijn
# - Alphen-Chaam
# - Altena
# - Ameland
# - Amersfoort
# - Amstelveen
# - Amsterdam
# - Apeldoorn
# - Arnhem
# - Assen
# - Asten
# - Baarle-Nassau
# - Baarn
# - Barendrecht
# - Barneveld
# - Beek
# - Beekdaelen
# - Beemster
# - Beesel
# - Berg en Dal
# - Bergeijk
# - Bergen (L.)
# - Bergen (NH.)
# - Bergen op Zoom
# - Berkelland
# - Bernheze
# - Best
# - Beuningen
# - Beverwijk
# - Bladel
# - Blaricum
# - Bloemendaal
# - Bodegraven-Reeuwijk
# - Boekel
# - Borger-Odoorn
# - Borne
# - Borsele
# - Boxmeer
# - Boxtel
# - Breda
# - Brielle
# - Bronckhorst
# - Brummen
# - Brunssum
# - Bunnik
# - Bunschoten
# - Buren
# - Capelle aan den IJssel
# - Castricum
# - Coevorden
# - Cranendonck
# - Cuijk
# - Culemborg
# - Dalfsen
# - Dantumadiel
# - De Bilt
# - De Fryske Marren
# - De Ronde Venen
# - De Wolden
# - Delft
# - Den Helder
# - Deurne
# - Deventer
# - Diemen
# - Dinkelland
# - Doesburg
# - Doetinchem
# - Dongen
# - Dordrecht
# - Drechterland
# - Drimmelen
# - Dronten
# - Druten
# - Duiven
# - Echt-Susteren
# - Edam-Volendam
# - Ede
# - Eemnes
# - Eemsdelta
# - Eersel
# - Eijsden-Margraten
# - Eindhoven
# - Elburg
# - Emmen
# - Enkhuizen
# - Enschede
# - Epe
# - Ermelo
# - Etten-Leur
# - Geertruidenberg
# - Geldrop-Mierlo
# - Gemert-Bakel
# - Gennep
# - Gilze en Rijen
# - Goeree-Overflakkee
# - Goes
# - Goirle
# - Gooise Meren
# - Gorinchem
# - Gouda
# - Grave
# - Groningen
# - Gulpen-Wittem
# - Haaksbergen
# - Haarlem
# - Haarlemmermeer
# - Halderberge
# - Hardenberg
# - Harderwijk
# - Hardinxveld-Giessendam
# - Harlingen
# - Hattem
# - Heemskerk
# - Heemstede
# - Heerde
# - Heerenveen
# - Heerhugowaard
# - Heerlen
# - Heeze-Leende
# - Heiloo
# - Hellendoorn
# - Hellevoetsluis
# - Helmond
# - Hendrik-Ido-Ambacht
# - Hengelo (O.)
# - Het Hogeland
# - Heumen
# - Heusden
# - Hillegom
# - Hilvarenbeek
# - Hilversum
# - Hoeksche Waard
# - Hof van Twente
# - Hollands Kroon
# - Hoogeveen
# - Hoorn
# - Horst aan de Maas
# - Houten
# - Huizen
# - Hulst
# - IJsselstein
# - Kaag en Braassem
# - Kampen
# - Kapelle
# - Katwijk
# - Kerkrade
# - Koggenland
# - Krimpen aan den IJssel
# - Krimpenerwaard
# - Laarbeek
# - Landerd
# - Landgraaf
# - Landsmeer
# - Langedijk
# - Lansingerland
# - Laren
# - Leeuwarden
# - Leiden
# - Leiderdorp
# - Leidschendam-Voorburg
# - Lelystad
# - Leudal
# - Leusden
# - Lingewaard
# - Lisse
# - Lochem
# - Loon op Zand
# - Lopik
# - Losser
# - Maasdriel
# - Maasgouw
# - Maassluis
# - Maastricht
# - Medemblik
# - Meerssen
# - Meierijstad
# - Meppel
# - Middelburg
# - Midden-Delfland
# - Midden-Drenthe
# - Midden-Groningen
# - Mill en Sint Hubert
# - Moerdijk
# - Molenlanden
# - Montferland
# - Montfoort
# - Mook en Middelaar
# - Neder-Betuwe
# - Nederweert
# - Netwerk Acute Zorg West
# - Nieuwegein
# - Nieuwkoop
# - Nijkerk
# - Nijmegen
# - Nissewaard
# - Noardeast-Fryslân
# - Noord-Beveland
# - Noordenveld
# - Noordoostpolder
# - Noordwijk
# - Nuenen, Gerwen en Nederwetten
# - Nunspeet
# - Oegstgeest
# - Oirschot
# - Oisterwijk
# - Oldambt
# - Oldebroek
# - Oldenzaal
# - Olst-Wijhe
# - Ommen
# - Oost Gelre
# - Oosterhout
# - Ooststellingwerf
# - Oostzaan
# - Opmeer
# - Opsterland
# - Oss
# - Oude IJsselstreek
# - Ouder-Amstel
# - Oudewater
# - Overbetuwe
# - Papendrecht
# - Peel en Maas
# - Pekela
# - Pijnacker-Nootdorp
# - Purmerend
# - Putten
# - Raalte
# - Reimerswaal
# - Renkum
# - Renswoude
# - Reusel-De Mierden
# - Rheden
# - Rhenen
# - Ridderkerk
# - Rijssen-Holten
# - Rijswijk
# - Roerdalen
# - Roermond
# - Roosendaal
# - Rotterdam
# - Rozendaal
# - Rucphen
# - Schagen
# - Scherpenzeel
# - Schiedam
# - Schiermonnikoog
# - Schouwen-Duiveland
# - Simpelveld
# - Sint Anthonis
# - Sint-Michielsgestel
# - Sittard-Geleen
# - Sliedrecht
# - Sluis
# - Smallingerland
# - Soest
# - Someren
# - Son en Breugel
# - Stadskanaal
# - Staphorst
# - Stede Broec
# - Steenbergen
# - Steenwijkerland
# - Stein
# - Stichtse Vecht
# - Súdwest-Fryslân
# - Terneuzen
# - Terschelling
# - Texel
# - Teylingen
# - Tholen
# - Tiel
# - Tilburg
# - Tubbergen
# - Twenterand
# - Tynaarlo
# - Tytsjerksteradiel
# - Uden
# - Uitgeest
# - Uithoorn
# - Urk
# - Utrecht
# - Utrechtse Heuvelrug
# - Vaals
# - Valkenburg aan de Geul
# - Valkenswaard
# - Veendam
# - Veenendaal
# - Veere
# - Veldhoven
# - Velsen
# - Venlo
# - Venray
# - Vijfheerenlanden
# - Vlaardingen
# - Vlieland
# - Vlissingen
# - Voerendaal
# - Voorschoten
# - Voorst
# - Vught
# - Waadhoeke
# - Waalre
# - Waalwijk
# - Waddinxveen
# - Wageningen
# - Wassenaar
# - Waterland
# - Weert
# - Weesp
# - West Betuwe
# - West Maas en Waal
# - Westerkwartier
# - Westerveld
# - Westervoort
# - Westerwolde
# - Westland
# - Weststellingwerf
# - Westvoorne
# - Wierden
# - Wijchen
# - Wijdemeren
# - Wijk bij Duurstede
# - Winterswijk
# - Woensdrecht
# - Woerden
# - Wormerland
# - Woudenberg
# - Zaanstad
# - Zaltbommel
# - Zandvoort
# - Zeewolde
# - Zeist
# - Zevenaar
# - Zoetermeer
# - Zoeterwoude
# - Zuidplas
# - Zundert
# - Zutphen
# - Zwartewaterland
# - Zwijndrecht
# - Zwolle

# %%
# TODO: FILL IN THE MUNICIPALITY YOU'RE INTERESTED IN HERE
municipality = 'Alphen-Chaam'
# DON'T MODIFY ANYTHING BELOW THIS LINE

reported = 0
for row in data_dicts:
    if row['Municipality_name'] == municipality:
        reported += row['Total_reported']
print(f'The total number of reported cases in {municipality} is {reported}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-5860e31fc865> in <module>()
#       6 for row in data_dicts:
#       7     if row['Municipality_name'] == municipality:
# ----> 8         reported += row['Total_reported']
#       9 print(f'The total number of reported cases in {municipality} is {reported}')
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %% [markdown]
# Because we have all the data types in order, we can also easily plot the development of new reported cases for that same municipality.

# %%
new_cases_per_day = defaultdict(int)
for row in data_dicts:
        if row['Municipality_name'] == municipality:
            new_cases_per_day[row['Date_of_publication']] += row['Total_reported']
new_cases_per_day = sorted(new_cases_per_day.items(), key=lambda x: x[0])

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day], [cases for _, cases in new_cases_per_day])
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases');
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-1f89f128ee6d> in <module>()
#       2 for row in data_dicts:
#       3         if row['Municipality_name'] == municipality:
# ----> 4             new_cases_per_day[row['Date_of_publication']] += row['Total_reported']
#       5 new_cases_per_day = sorted(new_cases_per_day.items(), key=lambda x: x[0])
#       6
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %% [markdown]
# ## Missing Data
#
# Finally, a visualization! Let's tackle one final problem: missing data. When we were looking at the metadata, we found that we have $22736$ missing or empty values. Let's print a few datapoints that contain missing values to see what we're dealing with exactly.

# %%
for i, row in enumerate(data_dicts):
    missing_keys = []
    for key, val in row.items():
        if val == '':
            missing_keys.append(key)
    if missing_keys:
        print(f'Row {i} contains empty values for: {missing_keys}')
# Out:
# Streaming output truncated to the last 5000 lines.
# Row 288191 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288192 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288193 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288194 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288195 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288196 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288197 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288198 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288199 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288200 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288201 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288202 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288203 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288204 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288205 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288206 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288207 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288208 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 288209 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288210 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288211 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288212 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288213 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288214 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288568 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288569 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288570 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288571 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288572 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288573 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288574 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288575 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288576 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288577 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288578 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288579 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288580 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288581 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288582 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288583 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288584 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288585 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288586 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 288587 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288588 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288589 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288590 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288591 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288592 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288946 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288947 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288948 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288949 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288950 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288951 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288952 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288953 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288954 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288955 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288956 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288957 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 288958 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288959 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288960 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288961 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288962 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288963 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288964 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 288965 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288966 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288967 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288968 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288969 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 288970 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289324 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289325 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289326 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289327 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289328 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289329 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289330 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289331 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289332 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289333 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289334 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289335 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289336 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289337 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289338 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289339 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289340 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289341 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289342 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 289343 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289344 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289345 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289346 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289347 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289348 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289702 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289703 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289704 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289705 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289706 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289707 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289708 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289709 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289710 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289711 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289712 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289713 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 289714 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289715 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289716 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289717 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289718 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289719 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289720 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 289721 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289722 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289723 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289724 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289725 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 289726 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290080 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290081 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290082 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290083 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290084 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290085 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290086 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290087 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290088 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290089 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290090 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290091 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290092 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290093 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290094 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290095 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290096 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290097 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290098 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 290099 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290100 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290101 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290102 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290103 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290104 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290458 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290459 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290460 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290461 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290462 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290463 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290464 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290465 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290466 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290467 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290468 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290469 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290470 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290471 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290472 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290473 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290474 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290475 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290476 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 290477 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290478 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290479 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290480 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290481 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290482 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290836 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290837 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290838 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290839 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290840 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290841 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290842 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290843 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290844 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290845 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290846 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290847 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 290848 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290849 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290850 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290851 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290852 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290853 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290854 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 290855 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290856 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290857 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290858 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290859 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 290860 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291214 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291215 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291216 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291217 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291218 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291219 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291220 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291221 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291222 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291223 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291224 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291225 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291226 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291227 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291228 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291229 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291230 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291231 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291232 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 291233 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291234 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291235 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291236 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291237 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291238 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291592 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291593 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291594 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291595 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291596 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291597 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291598 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291599 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291600 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291601 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291602 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291603 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291604 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291605 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291606 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291607 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291608 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291609 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291610 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 291611 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291612 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291613 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291614 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291615 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291616 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291970 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291971 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291972 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291973 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291974 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291975 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291976 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291977 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291978 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291979 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291980 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291981 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 291982 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291983 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291984 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291985 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291986 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291987 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291988 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 291989 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291990 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291991 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291992 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291993 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 291994 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292348 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292349 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292350 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292351 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292352 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292353 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292354 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292355 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292356 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292357 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292358 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292359 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292360 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292361 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292362 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292363 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292364 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292365 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292366 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 292367 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292368 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292369 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292370 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292371 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292372 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292726 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292727 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292728 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292729 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292730 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292731 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292732 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292733 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292734 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292735 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292736 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292737 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292738 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292739 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292740 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292741 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292742 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292743 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292744 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 292745 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292746 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292747 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292748 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292749 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292750 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292981 contains empty values for: ['Deceased']
# Row 292987 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292988 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292989 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292990 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292991 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292992 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292993 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292994 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292995 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292996 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292997 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 292998 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 292999 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293000 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293001 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293002 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293003 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293004 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293005 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 293006 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293007 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293008 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293009 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293010 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293011 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293365 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293366 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293367 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293368 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293369 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293370 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293371 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293372 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293373 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293374 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293375 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293376 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293377 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293378 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293379 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293380 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293381 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293382 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293383 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 293384 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293385 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293386 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293387 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293388 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293389 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293743 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293744 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293745 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293746 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293747 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293748 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293749 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293750 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293751 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293752 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293753 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293754 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 293755 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293756 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293757 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293758 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293759 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293760 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293761 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 293762 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293763 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293764 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293765 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293766 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 293767 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294121 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294122 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294123 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294124 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294125 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294126 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294127 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294128 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294129 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294130 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294131 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294132 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294133 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294134 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294135 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294136 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294137 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294138 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294139 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 294140 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294141 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294142 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294143 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294144 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294145 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294499 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294500 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294501 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294502 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294503 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294504 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294505 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294506 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294507 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294508 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294509 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294510 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294511 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294512 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294513 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294514 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294515 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294516 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294517 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 294518 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294519 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294520 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294521 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294522 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294523 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294877 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294878 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294879 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294880 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294881 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294882 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294883 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294884 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294885 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294886 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294887 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294888 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 294889 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294890 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294891 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294892 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294893 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294894 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294895 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 294896 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294897 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294898 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294899 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294900 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 294901 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295255 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295256 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295257 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295258 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295259 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295260 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295261 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295262 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295263 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295264 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295265 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295266 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295267 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295268 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295269 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295270 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295271 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295272 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295273 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 295274 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295275 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295276 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295277 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295278 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295279 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295633 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295634 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295635 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295636 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295637 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295638 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295639 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295640 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295641 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295642 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295643 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295644 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 295645 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295646 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295647 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295648 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295649 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295650 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295651 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 295652 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295653 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295654 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295655 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295656 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 295657 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296011 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296012 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296013 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296014 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296015 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296016 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296017 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296018 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296019 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296020 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296021 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296022 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296023 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296024 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296025 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296026 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296027 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296028 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296029 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 296030 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296031 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296032 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296033 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296034 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296035 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296389 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296390 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 296391 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 296392 contains empty values for: ['Municipality_code', 'Municipality_name']
# ...
# Row 360162 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360163 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360164 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 360165 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360166 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360167 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360168 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360169 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360170 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360524 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360525 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360526 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360527 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360528 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360529 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360530 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360531 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360532 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360533 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360534 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360535 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360536 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360537 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360538 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360539 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360540 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360541 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360542 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 360543 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360544 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360545 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360546 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360547 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360548 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360902 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360903 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360904 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360905 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360906 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360907 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360908 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360909 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360910 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360911 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360912 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360913 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 360914 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360915 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360916 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360917 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360918 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360919 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360920 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 360921 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360922 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360923 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360924 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360925 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 360926 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361280 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361281 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361282 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361283 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361284 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361285 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361286 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361287 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361288 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361289 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361290 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361291 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361292 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361293 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361294 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361295 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361296 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361297 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361298 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 361299 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361300 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361301 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361302 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361303 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361304 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361658 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361659 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361660 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361661 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361662 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361663 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361664 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361665 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361666 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361667 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361668 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361669 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 361670 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361671 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361672 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361673 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361674 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361675 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361676 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 361677 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361678 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361679 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361680 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361681 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 361682 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362036 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362037 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362038 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362039 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362040 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362041 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362042 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362043 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362044 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362045 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362046 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362047 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362048 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362049 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362050 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362051 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362052 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362053 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362054 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 362055 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362056 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362057 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362058 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362059 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362060 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362414 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362415 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362416 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362417 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362418 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362419 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362420 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362421 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362422 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362423 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362424 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362425 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362426 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362427 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362428 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362429 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362430 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362431 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362432 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 362433 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362434 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362435 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362436 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362437 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362438 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362792 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362793 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362794 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362795 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362796 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362797 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362798 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362799 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362800 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362801 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362802 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362803 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']
# Row 362804 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362805 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362806 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362807 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362808 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362809 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362810 contains empty values for: ['Municipality_code', 'Municipality_name', 'Security_region_code', 'Security_region_name']
# Row 362811 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362812 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362813 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362814 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362815 contains empty values for: ['Municipality_code', 'Municipality_name']
# Row 362816 contains empty values for: ['Municipality_code', 'Municipality_name', 'ROAZ_region']

# %% [markdown]
# **16. What column(s) is/are missing most often?**
#
# 'Municipality_code', 'Municipality_name
#
# Missing data may become a problem if we want to draw comparisons between certain parts of the data. Still, there is no universal and definitive *correct approach* to solving the problem of missing data. In fact, in this case there might actually not be a good way to fill in the missing municipalities here.
#
# For the sake of exercise, we will create a new dataset for your chosen municipality where the `Total_reported` new cases will be replaced with the impossible number `-1` from a number of the dates.
#
# **17. Why is `-1` an impossible number here?**
#
# Er kan niet een negatieve Covid 19 besmetting zijn. Er kan geen sprake zijn van een negatief getal.

# %%
noisy_new_cases_per_day = [(date, cases) if np.random.rand() < 0.8
                           else (date, -1)
                           for date, cases in new_cases_per_day]

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day],
        [cases for _, cases in new_cases_per_day], '.', label='true data')
ax.plot([date for date, _ in noisy_new_cases_per_day],
        [cases for _, cases in noisy_new_cases_per_day],
        label='noisy data')
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases')
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-12c262b87b2a> in <module>()
#       1 noisy_new_cases_per_day = [(date, cases) if np.random.rand() < 0.8
#       2                            else (date, -1)
# ----> 3                            for date, cases in new_cases_per_day]
#       4
#       5 fig, ax = plt.subplots(figsize=(16,9))
#
# <ipython-input-79-12c262b87b2a> in <listcomp>(.0)
#       1 noisy_new_cases_per_day = [(date, cases) if np.random.rand() < 0.8
#       2                            else (date, -1)
# ----> 3                            for date, cases in new_cases_per_day]
#       4
#       5 fig, ax = plt.subplots(figsize=(16,9))
#
# TypeError: cannot unpack non-iterable datetime.date object

# %% [markdown]
# This plot is a lot more messy than the clean data plot, in addition to also showing the impossible number `-1`.
#
# **18. What would be a good way to fill in the missing values? You will not need to implement them, so use your imagination.**
#
# De gemeente code invullen en de gemeente naam invullen. Code schrijven voor alle regels overal voor alle data die bij gemeente breda hoort dezelfde code invullen.
#
# Here we'll use the mean of the two surrounding dates' values. For example:
#
# 1. `2020-02-03` is missing
# 2. We take the values from the day before, `2020-02-02`, and the day after, `2020-02-04`. If the data from the day before or after is not available, we use the nearest available datapoint instead.
# 3. We add them up
# 4. Divide them by $2$
# 5. We insert the result as the value for `2020-02-03`.
#
# This is a simple way of doing **interpolation** -- estimating missing values within the range of the data we have. This is the opposite of **extrapolation**, where we have estimate values *outside* of the range of the data we have.
#
# Let's see what the implementation and the result look like.

# %%
interpolated_data = []
max_data_index = len(noisy_new_cases_per_day) - 1
for i, (date, x) in enumerate(noisy_new_cases_per_day):
    # If we have an impossible value
    if x == -1:
        delta_left = 1
        # Scan the left side for values that are not -1
        while noisy_new_cases_per_day[i - delta_left][1] == -1:
            delta_left += 1
            # If we're outside of the data we can't do interpolation. It would be extrapolation.
            if i - delta_left < 0:
                continue
    
        # Scan the right side for values that are not -1
        delta_right = 1
        while noisy_new_cases_per_day[i + delta_right][1] == -1:
            delta_right += 1
            # If we're outside of the data we can't do interpolation. It would be extrapolation.
            if i + delta_right > max_data_index:
                continue
        
        # Finally use the mean of two nearest useful values
        interpolated_value = ((noisy_new_cases_per_day[i - delta_left][1]
                               + noisy_new_cases_per_day[i + delta_right][1])
                              / 2)
        interpolated_data.append((date, interpolated_value))
    else:
        interpolated_data.append((date, x))

fig, ax = plt.subplots(figsize=(16,9))
ax.plot([date for date, _ in new_cases_per_day],
        [cases for _, cases in new_cases_per_day], '.', label='true data')
ax.plot([date for date, _ in interpolated_data],
        [cases for _, cases in interpolated_data],
        label='interpolated data')
ax.plot([date for (date, cases) in noisy_new_cases_per_day if cases == -1],
        [cases for _, cases in noisy_new_cases_per_day if cases == -1], '.',
        label='previously missing data')
ax.set_xlabel('Date')
ax.set_ylabel('Number of new cases')
ax.legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-c80698332c2a> in <module>()
#       1 interpolated_data = []
# ----> 2 max_data_index = len(noisy_new_cases_per_day) - 1
#       3 for i, (date, x) in enumerate(noisy_new_cases_per_day):
#       4     # If we have an impossible value
#       5     if x == -1:
#
# NameError: name 'noisy_new_cases_per_day' is not defined

# %% [markdown]
# **19. Is this a good way to fill in missing values, in your opinion? Explain.**
#
# Ja, Intrapolatie is een goede manier om missende waarden in te vullen, omdat je het gemiddelde van de dichtsbijzijnde waarden pakt. Dus zou een reele schatting moet zijn van de missende data.
#
# **20. In which cases will this way of filling in missing values work well, and when will it not work well at all? Give an example for both cases.**
#
# Het werkt wel als je veel data hebt die op een logische manier samen hangen, dus normaal verdeeld. Het werkt niet als je niet veel data hebt die niet op een logische manier samen hangen.

# %% [markdown]
# ## Conclusion
#
# Data preparation may not be the most glamorous part of data analytics, but it is quite important. If we do not do it well, every analytics step that comes after will suffer. It is as they say: *garbage in, garbage out*.
#
# It is also good to know that since most data preparation steps are quite general, there are plenty of tools that make doing it a lot easier and faster. All of the above filtering, selecting and interpolating can be done in a few lines of code! But now *you* know how it works under the hood, and why it's so important!
